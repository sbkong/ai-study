# %%
import torch, time

# %%
torch.version.cuda
# Out:
# '13.2'

# %%
p = torch.cuda.get_device_properties(0)

print(p.name)
print(p.total_memory / 1024 ** 3, "GiB")
print(p.multi_processor_count)
# Out:
# NVIDIA GeForce RTX 4060 Ti
# 15.99560546875 GiB
# 34
